# %% [markdown]
# <a href="https://colab.research.google.com/github/mingma1369/Python/blob/main/Lecture_18_Drop_Entry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
ser1=Series(np.arange(3),index=['a','b','c'])
ser1
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
ser1.drop('b')
# Out:
# a    0
# c    2
# dtype: int64

# %%
dframe1=DataFrame(np.arange(9).reshape((3,3)),index=['SF','LA','NY'],columns=['pop','size','year'])
dframe1
# Out:
#     pop  size  year
# SF    0     1     2
# LA    3     4     5
# NY    6     7     8

# %%
dframe1.drop('LA')
# Out:
#     pop  size  year
# SF    0     1     2
# NY    6     7     8

# %%
dframe1
# Out:
#     pop  size  year
# SF    0     1     2
# LA    3     4     5
# NY    6     7     8

# %%
dframe2=dframe1.drop('LA')
dframe2
# Out:
#     pop  size  year
# SF    0     1     2
# NY    6     7     8
