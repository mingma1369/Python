# %% [markdown]
# <a href="https://colab.research.google.com/github/mingma1369/Python/blob/main/Lecture_15_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lecture 15 DataFrame

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
nfl_frame=pd.read_csv('/content/sample_data/california_housing_train.csv')
nfl_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
nfl_frame.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
nfl_frame['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
nfl_frame.total_rooms
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64

# %%
DataFrame(nfl_frame,columns=['population','households','median_income'])
# Out:
#        population  households  median_income
# 0          1015.0       472.0         1.4936
# 1          1129.0       463.0         1.8200
# 2           333.0       117.0         1.6509
# 3           515.0       226.0         3.1917
# 4           624.0       262.0         1.9250
# ...           ...         ...            ...
# 16995       907.0       369.0         2.3571
# 16996      1194.0       465.0         2.5179
# 16997      1244.0       456.0         3.0313
# 16998      1298.0       478.0         1.9797
# 16999       806.0       270.0         3.0147
#
# [17000 rows x 3 columns]

# %%
DataFrame(nfl_frame,columns=['population','households','median_income','Stadium'])
# Out:
#        population  households  median_income  Stadium
# 0          1015.0       472.0         1.4936      NaN
# 1          1129.0       463.0         1.8200      NaN
# 2           333.0       117.0         1.6509      NaN
# 3           515.0       226.0         3.1917      NaN
# 4           624.0       262.0         1.9250      NaN
# ...           ...         ...            ...      ...
# 16995       907.0       369.0         2.3571      NaN
# 16996      1194.0       465.0         2.5179      NaN
# 16997      1244.0       456.0         3.0313      NaN
# 16998      1298.0       478.0         1.9797      NaN
# 16999       806.0       270.0         3.0147      NaN
#
# [17000 rows x 4 columns]

# %%
nfl_frame.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %%
nfl_frame.tail(3)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
nfl_frame.iloc[3]
# Out:
# longitude              -114.5700
# latitude                 33.6400
# housing_median_age       14.0000
# total_rooms            1501.0000
# total_bedrooms          337.0000
# population              515.0000
# households              226.0000
# median_income             3.1917
# median_house_value    73400.0000
# Name: 3, dtype: float64

# %%
nfl_frame['Stadium']="Levi's Stadium"
nfl_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
nfl_frame['Stadium']=np.arange(17000)
nfl_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
stadiums=Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium']=stadiums
nfl_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
del nfl_frame['Stadium']
nfl_frame
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...
