# %% [markdown]
# # Create Mortgage Amortization Schedule

# %% [markdown]
# ![title](img/peer-to-peer-mortgage.jpeg)

# %% [markdown]
# ## Part 1 - Mortgage Basics

# %% [markdown]
# ** Definition **<br>
# -  A mortgage is a <font color = red > loan </font> used to purchase a house.<br>
# -  A mortgage is a <font color = red > term loan </font>, secured by the collateral of specified real estate property, that the borrower is obliged to pay back with a predetermined set of payments.

# %% [markdown]
# ** Disclosure Statement ** <br>
# - A document outlining the specific terms and conditions of a loan, including the interest rate of the loan, any loan fees, the amount borrowed, insurance, prepayment rights and the responsibilities of the borrower.

# %% [markdown]
# ** Principal Amount ** <br>
# - The amount which you are borrowing from the bank.

# %% [markdown]
# ** Interest Rate ** <br>
# - The interest rate on your loan is a percentage of the loan amount that you pay the lender as the cost for borrowing money. A mortgage can have a fixed or variable interest rate.

# %% [markdown]
# ** Term ** <br>
# - The mortgage term is the length of time you commit to the mortgage rate, lender, and associated mortgage terms and conditions. The term you choose will have a direct effect on your mortgage rate, with short terms historically proven to be lower than long-term mortgage rates.
# - The term acts like a 'reset' button on a mortgage. When the term is up, you must renew your mortgage on the remaining principle, at a new rate available at the end of the term.

# %% [markdown]
# ** Amortization period ** <br>
# - The mortgage amortization period, on the other hand, is the length of time it will take you to pay off your entire mortgage.
# - Longer amortization periods reduce your monthly payments, as you are paying your mortgage off over a greater number of years. However, you will pay more interest over the life of the mortgage.

# %% [markdown]
# ** Monthly payment ** <br>
# - Your monthly payment is what you pay to the lender each month to repay your loan. The amount you pay every month depends on the terms of your mortgage loan. This includes the principal, which is the actual balance on the loan, and the interest on the loan.

# %% [markdown]
# ** Prepayment ** <br>
# - A privilege in a mortgage permitting the borrower to make payments in advance of their due date.

# %% [markdown]
# ** Amortization schedule **
# - An amortization schedule is a <font color = red > complete table of periodic loan payments </font>, showing the amount of principal and the amount of interest that comprise each payment until the loan is paid off at the end of its term.
# - While each periodic payment is the same amount early in the schedule, the majority of each payment is interest; later in the schedule, the majority of each payment covers the loan's principal. The last line of the schedule shows the borrower’s total interest and principal payments for the entire loan term. See excel file for more details.

# %% [markdown]
# ## Part 2 - Calculate Monthly Mortgage Payment

# %% [markdown]
# ![title](img/images.png)

# %% [markdown]
# ## Time value of money

# %% [markdown]
# ** Definition ** <br>
# - All things being equal, it is better to have money now rather than later.
# - Money available at the present time is worth more than the identical sum in the future due to its potential earning capacity. This core principle of finance holds that, provided money can earn interest, any amount of money is worth more the sooner it is received. TVM is also sometimes referred to as present discounted value.

# %% [markdown]
# ** Example ** <br>

# %% [markdown]
# Assume a sum of \$10,000 is invested for one year at 10% interest. <br>
# <br>
# The future value of that money is: <br>
# <br>
# FV = \$10,000 * (1 + 10%) = \$11,000 <br>
# <br>
# The formula can also be rearranged to find the value of the future sum in present day dollars. <br>
# <br>
# For example, the value of \$5,000 one year from today, compounded at 7% interest, is: <br>
# <br>
# PV = \$5,000 / (1 + 7%) = \$4,673

# %% [markdown]
# ** Annuity in Arrears ** <br>
# - Annuity in arrears refers to the payment of an <font color = red > equal </font> amount of money that is made at the end of a regular term. It does not refer to an annuity product but instead refers to a payment structure. Another way of describing annuity in arrears is a series of periodic, recurring payments that are due at the end of a predetermined period.
# - A common example of an annuity in arrears is a mortgage payment which consists of principal and interest payment.

# %% [markdown]
# <img src="img/time value formula1.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# <img src="img/time value formula2.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# ** Formula ** <br>

# %% [markdown]
# <img src="img/IMG_6483.JPG" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# ## Part 3 - Create Mortgage Amortization Schedule

# %% [markdown]
# ## 1 - Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# pd.set_option('display.max_rows', 10)
# pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## 2 - Helper functions ##

# %% [markdown]
# ### 2.1 - Compute sum of the first n terms of a geometric sequence
#
# Implement `sum_geometric_seq()`. You need to compute $S_n = a \frac{1 - r^n}{1 - r}$.

# %%
# Method 1
# Compute Sn using above formula. Raise warning "Common ratio cannot be 0" if r = 0.
def sum_geometric_seq(a,r,n):

    """
    Compute sum of the first n terms of a geometric sequence

    Arguments:
    a -- Scale factor, equal to the sequence's start value
    r -- r ≠ 0 is the common ratio
    n -- Number of terms
    
    Return:
    Sn -- sum_geometric_seq(a,r,n)
    """
    
    ### START CODE HERE ### (≈ 8 lines of code)  
    if r == 0:
        print("Common ratio cannot be 0")
    elif r == 1:
        Sn = n * a
        return Sn
    else:
        Sn = a * (1 - r**n) / (1 - r)
        return Sn    
    ### END CODE HERE ###

# %%
# Print out result.
### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 2, 3)
Sn = sum_geometric_seq(a,r,n)
### END CODE HERE ###
print("A geometric sequence has starting value = %.2f, common ratio = %.2f. The sum of its first %d terms = %.2f"
     %(a, r, n, Sn))

### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 1, 3)
Sn = sum_geometric_seq(a,r,n)
### END CODE HERE ###
print("A geometric sequence has starting value = %.2f, common ratio = %.2f. The sum of its first %d terms = %.2f"
     %(a, r, n, Sn))

### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 0, 3)
sum_geometric_seq(a,r,n)
### END CODE HERE ###
# Out:
# A geometric sequence has starting value = 4.00, common ratio = 2.00. The sum of its first 3 terms = 28.00
# A geometric sequence has starting value = 4.00, common ratio = 1.00. The sum of its first 3 terms = 12.00
# Common ratio cannot be 0

# %% [markdown]
# **Expected Output**:
#
# A geometric sequence has starting value = 4.00, common ratio = 2.00. The sum of its first 3 terms = 28.00
# A geometric sequence has starting value = 4.00, common ratio = 1.00. The sum of its first 3 terms = 12.00
# Common ratio cannot be 0

# %%
# Method 2
# Compute Sn using for loop. Raise warning "Common ratio cannot be 0" if r = 0.
def sum_geometric_seq(a,r,n):

    """
    Compute sum of the first n terms of a geometric sequence

    Arguments:
    a -- Scale factor, equal to the sequence's start value
    r -- r ≠ 0 is the common ratio
    n -- Number of terms
    
    Return:
    Sn -- sum_geometric_seq(a,r,n)
    """    
    
    ### START CODE HERE ### (≈ 8 lines of code)
    if r == 0:
        print("Common ratio cannot be 0")  
    
    else:
        Sn = 0
        for i in range(n):
            a_i = a * r ** i
            Sn += a_i
        return Sn    
    ### END CODE HERE ###

# %%
# Print out result.
### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 2, 3)
Sn = sum_geometric_seq(a,r,n)
### END CODE HERE ###
print("A geometric sequence has starting value = %.2f, common ratio = %.2f. The sum of its first %d terms = %.2f"
     %(a, r, n, Sn))

### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 1, 3)
Sn = sum_geometric_seq(a,r,n)
### END CODE HERE ###
print("A geometric sequence has starting value = %.2f, common ratio = %.2f. The sum of its first %d terms = %.2f"
     %(a, r, n, Sn))

### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 0, 3)
sum_geometric_seq(a,r,n)
### END CODE HERE ###
# Out:
# A geometric sequence has starting value = 4.00, common ratio = 2.00. The sum of its first 3 terms = 28.00
# A geometric sequence has starting value = 4.00, common ratio = 1.00. The sum of its first 3 terms = 12.00
# Common ratio cannot be 0

# %% [markdown]
# **Expected Output**:
#
# A geometric sequence has starting value = 4.00, common ratio = 2.00. The sum of its first 3 terms = 28.00
# A geometric sequence has starting value = 4.00, common ratio = 1.00. The sum of its first 3 terms = 12.00
# Common ratio cannot be 0

# %%
# Method 3
# Compute Sn using np.geomspace. Raise warning "Common ratio cannot be 0" if r = 0.
# https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.geomspace.html
def sum_geometric_seq(a,r,n):
    
    """
    Compute sum of the first n terms of a geometric sequence

    Arguments:
    a -- Scale factor, equal to the sequence's start value
    r -- r ≠ 0 is the common ratio
    n -- Number of terms
    
    Return:
    Sn -- sum_geometric_seq(a,r,n)
    """    
    
    ### START CODE HERE ### (≈ 5 lines of code)
    if r == 0:
        print("Common ratio cannot be 0")
    
    else:
        Sn = np.geomspace(a, a*r**(n-1), num=n).sum()    
        return Sn    
    ### END CODE HERE ###

# %%
# Print out result.
### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 2, 3)
Sn = sum_geometric_seq(a,r,n)
### END CODE HERE ###
print("A geometric sequence has starting value = %.2f, common ratio = %.2f. The sum of its first %d terms = %.2f"
     %(a, r, n, Sn))

### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 1, 3)
Sn = sum_geometric_seq(a,r,n)
### END CODE HERE ###
print("A geometric sequence has starting value = %.2f, common ratio = %.2f. The sum of its first %d terms = %.2f"
     %(a, r, n, Sn))

### START CODE HERE ### (≈ 2 lines of code)
a, r, n = (4, 0, 3)
sum_geometric_seq(a,r,n)
### END CODE HERE ###
# Out:
# A geometric sequence has starting value = 4.00, common ratio = 2.00. The sum of its first 3 terms = 28.00
# A geometric sequence has starting value = 4.00, common ratio = 1.00. The sum of its first 3 terms = 12.00
# Common ratio cannot be 0

# %% [markdown]
# **Expected Output**:
#
# A geometric sequence has starting value = 4.00, common ratio = 2.00. The sum of its first 3 terms = 28.00
# A geometric sequence has starting value = 4.00, common ratio = 1.00. The sum of its first 3 terms = 12.00
# Common ratio cannot be 0

# %% [markdown]
# ### 2.2 - Compute monthly mortgage payment
#
# $ PMT = \frac{BAL}{D} $, where $ D = \sum_{i=1}^n (\frac{1}{1+r})^i $

# %%
def mth_mtg_pmt(Bal, Rate, Period):
    
    """
    Compute monthly mortgage payment

    Arguments:
    Bal    -- Initial balance or Current outstanding balance
    Rate   -- Annual interest rate in percentage
    Period -- Amortization period or Remaining amortization period 
    
    Return:
    Pmt -- mth_mtg_pmt(Bal, Rate, Term)
    """
    
    #Calculate monthly interest rate
    ### START CODE HERE ### (≈ 1 line of code)
    mRate = Rate/12/100
    ### END CODE HERE ###
    
    #Calculate monthly mortgage payment using above defined helper function
    ### START CODE HERE ### (≈ 5 lines of code)
    a = 1 / (1 + mRate)
    r = 1 / (1 + mRate)
    n = Period * 12
    D = sum_geometric_seq(a,r,n)
    
    Pmt = Bal / D
    ### END CODE HERE ###

    return Pmt

# %%
# Print out result.
### START CODE HERE ### (≈ 2 lines of code)
bal, rate, period = (760000, 2.19, 25)
pmt = mth_mtg_pmt(Bal = bal, Rate = rate, Period = period)
### END CODE HERE ###
print("When balance = " + str(bal) + ", annual interest rate = " + str(rate) + 
      "%, amortization period = " + str(period) + ",")
print("monthly mortgage payment is: " + str(round(pmt,2)))
# Out:
# When balance = 760000, annual interest rate = 2.19%, amortization period = 25,
# monthly mortgage payment is: 3292.06

# %% [markdown]
# **Expected Output**:
#
# When balance = 760000, annual interest rate = 2.19%, amortization period = 25,
# monthly mortgage payment is: 3292.06

# %% [markdown]
# ## 3 - Create mortgage amortization schedule

# %%
def create_mtg_amortization_schedule(Bal, Rate, Period):

    """
    Create mortgage amortization schedule

    Arguments:
    Bal    -- Current outstanding balance
    Rate   -- Annual interest rate in percentage
    Period -- Amortization Period
    
    Returns:
    res -- Nested list. Mortgage amortization schedule including payment number, outstanding balance, monthly payment,
           interest payment, cumulative interest payment, principal payment, cumulative principal payment
    """
    
    # Parameter initialization
    ### START CODE HERE ### (≈ 4 lines of code)
    res = []
    CumIntPaid = 0
    CumPpPaid = 0
    CumPrePaid = 0
    ### END CODE HERE ###
    
    # Calculate monthly mortgage payment based on current balance, 
    # annual interest rate and remaining amortization period
    ### START CODE HERE ### (≈ 1 line of code)
    pmt = mth_mtg_pmt(Bal, Rate, Period)
    ### END CODE HERE ###
    
    # Create mortgage amortization cash flow
    ### START CODE HERE ### (≈ 1 line of code)
    for i in range(1, Period * 12 + 1):
    ### END CODE HERE ###
    
        # Interest Payment
        # Calculate interest payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        IntPmt = Bal * Rate/100/12
        ### END CODE HERE ###
        # Calculate cumulative interest payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        CumIntPaid = CumIntPaid + IntPmt
        ### END CODE HERE ###

        # Principal Payment
        # Calculate principal payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        PpPmt = pmt - IntPmt
        ### END CODE HERE ###
        # Calculate cumulative principal payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        CumPpPaid = CumPpPaid + PpPmt
        ### END CODE HERE ###
        
        # Outstanding Balance
        # Calculate outstanding banlance as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        Bal = Bal - PpPmt
        ### END CODE HERE ###

        # Create mortgage payment cash flow
        ### START CODE HERE ### (≈ 1 line of code)
        res.append([i, Bal, pmt, IntPmt, CumIntPaid, PpPmt, CumPpPaid])
        ### END CODE HERE ###

    return res

# %%
# Print out first two payments given balance = 760000, anuual interest rate is 2.19%, amortization period is 25 years.
### START CODE HERE ### (≈ 1 line of code)
CashFlow = create_mtg_amortization_schedule(Bal = 760000, Rate = 2.19, Period = 25)
### END CODE HERE ###
print('First Payment:', [int(i) for i in CashFlow[0]]) #list comprehension
print('Second Payment:', [int(i) for i in CashFlow[1]])
# Out:
# First Payment: [1, 758094, 3292, 1387, 1387, 1905, 1905]
# Second Payment: [2, 756186, 3292, 1383, 2770, 1908, 3813]

# %% [markdown]
# **Expected Output**:
# First Payment: [1, 758094, 3292, 1387, 1387, 1905, 1905]
# Second Payment: [2, 756186, 3292, 1383, 2770, 1908, 3813]

# %% [markdown]
# ## 4 - Convert list of cash flow into pandas DataFrame

# %%
# pandas documentation http://pandas.pydata.org/pandas-docs/stable/index.html
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html
def to_Pandas(res, FirstPmtDate, Period):
    
    '''
    Create mortgage amortization schedule in Pandas DataFrame format

    Arguments:
    res -- result from create_mtg_amortization_schedule(Bal, Rate, Period)
    FirstPmtDate -- String. yyyymmdd.
    Period -- Amortization Period.
    
    Returns:
    result -- Pandas DataFrame. Complete Mortgage amortization schedule.
    '''
    
    # Convert mortgage amortization schedule from nested list to Pandas DataFrame and 
    # round all columns to 2 decimal places.
    ### START CODE HERE ### (≈ 1 line of code)
    result = pd.DataFrame(res).round(2) 
    ### END CODE HERE ###
    
    # Add column names
    ### START CODE HERE ### (≈ 1 line of code)
    result.columns = ['PmtNo', 'OutstandingBal', 'MthPmt', 'IntPmt', 'TotIntPaid',
                      'PrincipalPmt', 'TotPrincipalPaid']
    ### END CODE HERE ###

    # Add Payment date column
    ### START CODE HERE ### (≈ 1 line of code)
    result['PmtDate'] = pd.date_range(start='20170501', periods=Period*12, freq='MS')
    ### END CODE HERE ###
    
    # Customize column order
    ### START CODE HERE ### (≈ 1 line of code)
    result = result[['PmtDate','PmtNo', 'OutstandingBal', 'MthPmt', 'IntPmt', 'TotIntPaid',
               'PrincipalPmt', 'TotPrincipalPaid']]
    ### END CODE HERE ###
    
    return result

# %%
# Expected Output:
### START CODE HERE ### (≈ 1 line of code)
result = to_Pandas(res = CashFlow, FirstPmtDate = '20170501', Period = 25)
### END CODE HERE ###
result
# Out:
#        PmtDate  PmtNo  OutstandingBal   MthPmt   IntPmt  TotIntPaid  \
# 0   2017-05-01      1       758094.94  3292.06  1387.00     1387.00
# 1   2017-06-01      2       756186.41  3292.06  1383.52     2770.52
# 2   2017-07-01      3       754274.40  3292.06  1380.04     4150.56
# 3   2017-08-01      4       752358.89  3292.06  1376.55     5527.11
# 4   2017-09-01      5       750439.89  3292.06  1373.05     6900.17
# 5   2017-10-01      6       748517.39  3292.06  1369.55     8269.72
# 6   2017-11-01      7       746591.38  3292.06  1366.04     9635.77
# 7   2017-12-01      8       744661.85  3292.06  1362.53    10998.30
# 8   2018-01-01      9       742728.80  3292.06  1359.01    12357.30
# 9   2018-02-01     10       740792.23  3292.06  1355.48    13712.78
# 10  2018-03-01     11       738852.12  3292.06  1351.95    15064.73
# 11  2018-04-01     12       736908.47  3292.06  1348.41    16413.13
# 12  2018-05-01     13       734961.27  3292.06  1344.86    17757.99
# 13  2018-06-01     14       733010.52  3292.06  1341.30    19099.30
# 14  2018-07-01     15       731056.21  3292.06  1337.74    20437.04
# 15  2018-08-01     16       729098.33  3292.06  1334.18    21771.22
# 16  2018-09-01     17       727136.88  3292.06  1330.60    23101.82
# 17  2018-10-01     18       725171.85  3292.06  1327.02    24428.85
# 18  2018-11-01     19       723203.23  3292.06  1323.44    25752.29
# 19  2018-12-01     20       721231.02  3292.06  1319.85    27072.13
# 20  2019-01-01     21       719255.21  3292.06  1316.25    28388.38
# 21  2019-02-01     22       717275.80  3292.06  1312.64    29701.02
# 22  2019-03-01     23       715292.77  3292.06  1309.03    31010.05
# 23  2019-04-01     24       713306.13  3292.06  1305.41    32315.46
# 24  2019-05-01     25       711315.86  3292.06  1301.78    33617.24
# 25  2019-06-01     26       709321.95  3292.06  1298.15    34915.39
# 26  2019-07-01     27       707324.41  3292.06  1294.51    36209.90
# 27  2019-08-01     28       705323.22  3292.06  1290.87    37500.77
# 28  2019-09-01     29       703318.38  3292.06  1287.21    38787.99
# 29  2019-10-01     30       701309.88  3292.06  1283.56    40071.54
# ..         ...    ...             ...      ...      ...         ...
# 270 2039-11-01    271        92904.70  3292.06   175.24   225051.73
# 271 2039-12-01    272        89782.20  3292.06   169.55   225221.28
# 272 2040-01-01    273        86653.99  3292.06   163.85   225385.13
# 273 2040-02-01    274        83520.08  3292.06   158.14   225543.27
# 274 2040-03-01    275        80380.45  3292.06   152.42   225695.70
# 275 2040-04-01    276        77235.09  3292.06   146.69   225842.39
# 276 2040-05-01    277        74083.99  3292.06   140.95   225983.35
# 277 2040-06-01    278        70927.14  3292.06   135.20   226118.55
# 278 2040-07-01    279        67764.52  3292.06   129.44   226247.99
# 279 2040-08-01    280        64596.14  3292.06   123.67   226371.66
# 280 2040-09-01    281        61421.97  3292.06   117.89   226489.55
# 281 2040-10-01    282        58242.01  3292.06   112.10   226601.64
# 282 2040-11-01    283        55056.25  3292.06   106.29   226707.94
# 283 2040-12-01    284        51864.67  3292.06   100.48   226808.41
# 284 2041-01-01    285        48667.27  3292.06    94.65   226903.07
# 285 2041-02-01    286        45464.03  3292.06    88.82   226991.88
# 286 2041-03-01    287        42254.95  3292.06    82.97   227074.86
# 287 2041-04-01    288        39040.01  3292.06    77.12   227151.97
# 288 2041-05-01    289        35819.20  3292.06    71.25   227223.22
# 289 2041-06-01    290        32592.51  3292.06    65.37   227288.59
# 290 2041-07-01    291        29359.94  3292.06    59.48   227348.07
# 291 2041-08-01    292        26121.46  3292.06    53.58   227401.65
# 292 2041-09-01    293        22877.08  3292.06    47.67   227449.32
# 293 2041-10-01    294        19626.78  3292.06    41.75   227491.08
# 294 2041-11-01    295        16370.54  3292.06    35.82   227526.89
# 295 2041-12-01    296        13108.36  3292.06    29.88   227556.77
# 296 2042-01-01    297         9840.23  3292.06    23.92   227580.69
# 297 2042-02-01    298         6566.13  3292.06    17.96   227598.65
# 298 2042-03-01    299         3286.06  3292.06    11.98   227610.63
# 299 2042-04-01    300            0.00  3292.06     6.00   227616.63
#
#      PrincipalPmt  TotPrincipalPaid
# 0         1905.06           1905.06
# 1         1908.53           3813.59
# 2         1912.02           5725.60
# 3         1915.50           7641.11
# 4         1919.00           9560.11
# 5         1922.50          11482.61
# 6         1926.01          13408.62
# 7         1929.53          15338.15
# 8         1933.05          17271.20
# 9         1936.58          19207.77
# 10        1940.11          21147.88
# 11        1943.65          23091.53
# 12        1947.20          25038.73
# 13        1950.75          26989.48
# 14        1954.31          28943.79
# 15        1957.88          30901.67
# 16        1961.45          32863.12
# 17        1965.03          34828.15
# 18        1968.62          36796.77
# 19        1972.21          38768.98
# 20        1975.81          40744.79
# 21        1979.41          42724.20
# 22        1983.03          44707.23
# 23        1986.65          46693.87
# 24        1990.27          48684.14
# 25        1993.90          50678.05
# 26        1997.54          52675.59
# 27        2001.19          54676.78
# 28        2004.84          56681.62
# 29        2008.50          58690.12
# ..            ...               ...
# 270       3116.82         667095.30
# 271       3122.50         670217.80
# 272       3128.20         673346.01
# 273       3133.91         676479.92
# 274       3139.63         679619.55
# 275       3145.36         682764.91
# 276       3151.10         685916.01
# 277       3156.85         689072.86
# 278       3162.61         692235.48
# 279       3168.39         695403.86
# 280       3174.17         698578.03
# 281       3179.96         701757.99
# 282       3185.76         704943.75
# 283       3191.58         708135.33
# 284       3197.40         711332.73
# 285       3203.24         714535.97
# 286       3209.08         717745.05
# 287       3214.94         720959.99
# 288       3220.81         724180.80
# 289       3226.69         727407.49
# 290       3232.57         730640.06
# 291       3238.47         733878.54
# 292       3244.38         737122.92
# 293       3250.30         740373.22
# 294       3256.24         743629.46
# 295       3262.18         746891.64
# 296       3268.13         750159.77
# 297       3274.10         753433.87
# 298       3280.07         756713.94
# 299       3286.06         760000.00
#
# [300 rows x 8 columns]

# %% [raw]
# result.to_csv('mtg_amort_table.csv')

# %% [markdown]
# ## 5 - Plot

# %%
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html
### START CODE HERE ### (≈ 4 lines of code)
ax1 = plt.plot(result['PmtNo'], result['TotIntPaid'], label='CumulativeInterestPaid')
ax2 = plt.plot(result['PmtNo'], result['TotPrincipalPaid'], label='CumulativePrincipalPaid')
ax3 = plt.plot(result['PmtNo'], result['OutstandingBal'], label='OutstandingBalance')
plt.legend()
### END CODE HERE ###
plt.show()

# %%
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.stackplot.html
# https://matplotlib.org/gallery/lines_bars_and_markers/stackplot_demo.html
### START CODE HERE ### (≈ 2 lines of code)
plt.stackplot(result['PmtNo'], result['PrincipalPmt'], result['IntPmt'], labels=['PrincipalPayment','InterestPayment'])
plt.legend(loc='upper left')
### END CODE HERE ###
plt.show()

# %% [markdown]
# ## Part 4 - Advanced: Prepayment

# %%
def create_mtg_amortization_schedule(Bal, Rate, Period, PrePmt = {}):
    
    """
    Create mortgage amortization schedule

    Arguments:
    Bal    -- Current outstanding balance
    Rate   -- Annual interest rate in percentage
    Period -- Amortization Period
    PrePmt -- dict, Optional. 
              Prepayment between ith and (i+1)th payment
    
    Returns:
    res -- Nested list. Mortgage amortization schedule including payment number, outstanding balance, monthly payment,
           interest payment, cumulative interest payment, principal payment, cumulative principal payment,
           prepayment amount, cumulative prepayment amount
    """
    
    # Parameter initialization
    ### START CODE HERE ### (≈ 4 lines of code)
    res = []
    CumIntPaid = 0
    CumPpPaid = 0
    CumPrePaid = 0
    ### END CODE HERE ###
    
    # Calculate monthly mortgage payment based on current balance, 
    # annual interest rate and remaining amortization period
    ### START CODE HERE ### (≈ 1 line of code)
    pmt = mth_mtg_pmt(Bal, Rate, Period)
    ### END CODE HERE ###
    
    # Create mortgage amortization cash flow
    ### START CODE HERE ### (≈ 1 line of code)
    for i in range(1, Period * 12 + 1):
    ### END CODE HERE ###    
    
        # Interest Payment
        # Calculate interest payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        IntPmt = Bal * Rate/100/12
        ### END CODE HERE ###    
        
        # Calculate cumulative interest payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        CumIntPaid = CumIntPaid + IntPmt
        ### END CODE HERE ###  
        
        # Prepayment
        # Set prepayment value if there is a prepayment on ith mortgage payment date, set to 0 otherwise.
        ### START CODE HERE ### (≈ 4 lines of code)
        if i in PrePmt:
            PrePmtVal = PrePmt[i]
        else:
            PrePmtVal = 0
        ### END CODE HERE ###

        # Raise warning if prepayment amount is more than current balance and stop creating the cash flow.
        ### START CODE HERE ### (≈ 3 lines of code)
        if PrePmtVal > Bal:
            print('Prepayment amount cannot exceed current balance!')
            break
        ### END CODE HERE ###

        # Calculate cumulative prepayment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        CumPrePaid = CumPrePaid + PrePmtVal
        ### END CODE HERE ###
        
        # Principal Payment
        # Calculate principal payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        PpPmt = pmt - IntPmt + PrePmtVal
        ### END CODE HERE ###

        # Outstanding Balance
        # Calculate outstanding banlance as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        Bal = Bal - PpPmt
        ### END CODE HERE ###

        # Adjust payment amount on ith mortgage payment date if outstanding balance is negative after ith payment
        ### START CODE HERE ### (≈ 8 lines of code)
        if Bal < 0:
            Bal = Bal + PpPmt
            pmt = IntPmt + Bal
            PpPmt = Bal
            CumPpPaid = CumPpPaid + PpPmt
            Bal = 0
            res.append([i, Bal, pmt, IntPmt, CumIntPaid, PpPmt, CumPpPaid, PrePmtVal, CumPrePaid])
            break
        ### END CODE HERE ###
        
        # Calculate cumulative principal payment as of ith mortgage payment date
        ### START CODE HERE ### (≈ 1 line of code)
        CumPpPaid = CumPpPaid + PpPmt
        ### END CODE HERE ###
        
        # Create mortgage payment cash flow
        ### START CODE HERE ### (≈ 1 line of code)
        res.append([i, Bal, pmt, IntPmt, CumIntPaid, PpPmt, CumPpPaid, PrePmtVal, CumPrePaid])         
        ### END CODE HERE ###
        
    return res

# %%
# Print out first four payments given balance = 760000, anuual interest rate is 2.19%, 
# amortization period is 25 years and 
# prepayments were made on the third and fifth payment date with 300000 and 100000 dollars.
### START CODE HERE ### (≈ 1 line of code)
CashFlow = create_mtg_amortization_schedule(Bal = 760000, Rate = 2.19, Period = 25
                                           , PrePmt = {3:300000,5:100000})
### END CODE HERE ###
print('First Payment:', [int(i) for i in CashFlow[0]])
print('Second Payment:', [int(i) for i in CashFlow[1]])
print('Third Payment:', [int(i) for i in CashFlow[2]])
print('Forth Payment:', [int(i) for i in CashFlow[3]])
# Out:
# First Payment: [1, 758094, 3292, 1387, 1387, 1905, 1905, 0, 0]
# Second Payment: [2, 756186, 3292, 1383, 2770, 1908, 3813, 0, 0]
# Third Payment: [3, 454274, 3292, 1380, 4150, 301912, 305725, 300000, 300000]
# Forth Payment: [4, 451811, 3292, 829, 4979, 2463, 308188, 0, 300000]

# %% [markdown]
# **Expected Output**:
# First Payment: [1, 758094, 3292, 1387, 1387, 1905, 1905, 0, 0]
# Second Payment: [2, 756186, 3292, 1383, 2770, 1908, 3813, 0, 0]
# Third Payment: [3, 454274, 3292, 1380, 4150, 301912, 305725, 300000, 300000]
# Forth Payment: [4, 451811, 3292, 829, 4979, 2463, 308188, 0, 300000]

# %%
def to_Pandas(res, FirstPmtDate, Period):
    
    '''
    Create mortgage amortization schedule in Pandas DataFrame format

    Arguments:
    res -- result from create_mtg_amortization_schedule(Bal, Rate, Period)
    FirstPmtDate -- String. yyyymmdd.
    Period -- Amortization Period.
    
    Returns:
    result -- Pandas DataFrame. Complete Mortgage amortization schedule.
    '''
    
    # Convert mortgage amortization schedule from nested list to Pandas DataFrame and 
    # round all columns to 2 decimal places.
    ### START CODE HERE ### (≈ 1 line of code)
    result = pd.DataFrame(res).round(2) 
    ### END CODE HERE ###
     
    # Add column names
    ### START CODE HERE ### (≈ 1 line of code)
    result.columns = (['PmtNo', 'OutstandingBal', 'MthPmt', 'IntPmt', 'TotIntPaid',
                    'PrincipalPmt', 'TotPrincipalPaid', 'PrePmt', 'TotPrePmtPaid'])
    ### END CODE HERE ###
    
    # Add Payment date column    
    ### START CODE HERE ### (≈ 1 line of code)
    result['PmtDate'] = pd.date_range(start=FirstPmtDate, periods=result.shape[0], freq='MS')
    ### END CODE HERE ###
    
    # Customize column order
    ### START CODE HERE ### (≈ 1 line of code)  
    result = result[['PmtDate','PmtNo', 'OutstandingBal', 'MthPmt', 'IntPmt', 'TotIntPaid',
               'PrincipalPmt', 'TotPrincipalPaid', 'PrePmt', 'TotPrePmtPaid']]
    ### END CODE HERE ###
    
    return result

# %%
# Expected Output:
### START CODE HERE ### (≈ 1 line of code)
to_Pandas(res = CashFlow, FirstPmtDate = '20170501', Period = 25)
### END CODE HERE ###
# Out:
#        PmtDate  PmtNo  OutstandingBal   MthPmt   IntPmt  TotIntPaid  \
# 0   2017-05-01      1       758094.94  3292.06  1387.00     1387.00
# 1   2017-06-01      2       756186.41  3292.06  1383.52     2770.52
# 2   2017-07-01      3       454274.40  3292.06  1380.04     4150.56
# 3   2017-08-01      4       451811.39  3292.06   829.05     4979.61
# 4   2017-09-01      5       349343.89  3292.06   824.56     5804.17
# 5   2017-10-01      6       346689.39  3292.06   637.55     6441.72
# 6   2017-11-01      7       344030.04  3292.06   632.71     7074.43
# 7   2017-12-01      8       341365.84  3292.06   627.85     7702.29
# 8   2018-01-01      9       338696.78  3292.06   622.99     8325.28
# 9   2018-02-01     10       336022.85  3292.06   618.12     8943.40
# 10  2018-03-01     11       333344.03  3292.06   613.24     9556.64
# 11  2018-04-01     12       330660.33  3292.06   608.35    10164.99
# 12  2018-05-01     13       327971.73  3292.06   603.46    10768.45
# 13  2018-06-01     14       325278.22  3292.06   598.55    11367.00
# 14  2018-07-01     15       322579.80  3292.06   593.63    11960.63
# 15  2018-08-01     16       319876.45  3292.06   588.71    12549.34
# 16  2018-09-01     17       317168.17  3292.06   583.77    13133.11
# 17  2018-10-01     18       314454.95  3292.06   578.83    13711.95
# 18  2018-11-01     19       311736.77  3292.06   573.88    14285.83
# 19  2018-12-01     20       309013.64  3292.06   568.92    14854.75
# 20  2019-01-01     21       306285.53  3292.06   563.95    15418.70
# 21  2019-02-01     22       303552.45  3292.06   558.97    15977.67
# 22  2019-03-01     23       300814.37  3292.06   553.98    16531.65
# 23  2019-04-01     24       298071.31  3292.06   548.99    17080.64
# 24  2019-05-01     25       295323.23  3292.06   543.98    17624.62
# 25  2019-06-01     26       292570.14  3292.06   538.96    18163.58
# 26  2019-07-01     27       289812.02  3292.06   533.94    18697.52
# 27  2019-08-01     28       287048.88  3292.06   528.91    19226.43
# 28  2019-09-01     29       284280.68  3292.06   523.86    19750.29
# 29  2019-10-01     30       281507.44  3292.06   518.81    20269.10
# ..         ...    ...             ...      ...      ...         ...
# 94  2025-03-01     95        89955.33  3292.06   169.87    42700.60
# 95  2025-04-01     96        86827.44  3292.06   164.17    42864.76
# 96  2025-05-01     97        83693.85  3292.06   158.46    43023.22
# 97  2025-06-01     98        80554.53  3292.06   152.74    43175.97
# 98  2025-07-01     99        77409.49  3292.06   147.01    43322.98
# 99  2025-08-01    100        74258.71  3292.06   141.27    43464.25
# 100 2025-09-01    101        71102.17  3292.06   135.52    43599.77
# 101 2025-10-01    102        67939.88  3292.06   129.76    43729.53
# 102 2025-11-01    103        64771.81  3292.06   123.99    43853.52
# 103 2025-12-01    104        61597.97  3292.06   118.21    43971.73
# 104 2026-01-01    105        58418.33  3292.06   112.42    44084.15
# 105 2026-02-01    106        55232.89  3292.06   106.61    44190.76
# 106 2026-03-01    107        52041.63  3292.06   100.80    44291.56
# 107 2026-04-01    108        48844.55  3292.06    94.98    44386.54
# 108 2026-05-01    109        45641.64  3292.06    89.14    44475.68
# 109 2026-06-01    110        42432.88  3292.06    83.30    44558.98
# 110 2026-07-01    111        39218.26  3292.06    77.44    44636.42
# 111 2026-08-01    112        35997.78  3292.06    71.57    44707.99
# 112 2026-09-01    113        32771.42  3292.06    65.70    44773.68
# 113 2026-10-01    114        29539.17  3292.06    59.81    44833.49
# 114 2026-11-01    115        26301.03  3292.06    53.91    44887.40
# 115 2026-12-01    116        23056.97  3292.06    48.00    44935.40
# 116 2027-01-01    117        19806.99  3292.06    42.08    44977.48
# 117 2027-02-01    118        16551.09  3292.06    36.15    45013.63
# 118 2027-03-01    119        13289.24  3292.06    30.21    45043.83
# 119 2027-04-01    120        10021.43  3292.06    24.25    45068.09
# 120 2027-05-01    121         6747.67  3292.06    18.29    45086.38
# 121 2027-06-01    122         3467.93  3292.06    12.31    45098.69
# 122 2027-07-01    123          182.20  3292.06     6.33    45105.02
# 123 2027-08-01    124            0.00   182.53     0.33    45105.35
#
#      PrincipalPmt  TotPrincipalPaid  PrePmt  TotPrePmtPaid
# 0         1905.06           1905.06       0              0
# 1         1908.53           3813.59       0              0
# 2       301912.02         305725.60  300000         300000
# 3         2463.00         308188.61       0         300000
# 4       102467.50         410656.11  100000         400000
# 5         2654.50         413310.61       0         400000
# 6         2659.35         415969.96       0         400000
# 7         2664.20         418634.16       0         400000
# 8         2669.06         421303.22       0         400000
# 9         2673.93         423977.15       0         400000
# 10        2678.81         426655.97       0         400000
# 11        2683.70         429339.67       0         400000
# 12        2688.60         432028.27       0         400000
# 13        2693.51         434721.78       0         400000
# 14        2698.42         437420.20       0         400000
# 15        2703.35         440123.55       0         400000
# 16        2708.28         442831.83       0         400000
# 17        2713.22         445545.05       0         400000
# 18        2718.18         448263.23       0         400000
# 19        2723.14         450986.36       0         400000
# 20        2728.11         453714.47       0         400000
# 21        2733.08         456447.55       0         400000
# 22        2738.07         459185.63       0         400000
# 23        2743.07         461928.69       0         400000
# 24        2748.08         464676.77       0         400000
# 25        2753.09         467429.86       0         400000
# 26        2758.11         470187.98       0         400000
# 27        2763.15         472951.12       0         400000
# 28        2768.19         475719.32       0         400000
# 29        2773.24         478492.56       0         400000
# ..            ...               ...     ...            ...
# 94        3122.19         670044.67       0         400000
# 95        3127.89         673172.56       0         400000
# 96        3133.60         676306.15       0         400000
# 97        3139.31         679445.47       0         400000
# 98        3145.04         682590.51       0         400000
# 99        3150.78         685741.29       0         400000
# 100       3156.53         688897.83       0         400000
# 101       3162.29         692060.12       0         400000
# 102       3168.07         695228.19       0         400000
# 103       3173.85         698402.03       0         400000
# 104       3179.64         701581.67       0         400000
# 105       3185.44         704767.11       0         400000
# 106       3191.26         707958.37       0         400000
# 107       3197.08         711155.45       0         400000
# 108       3202.91         714358.36       0         400000
# 109       3208.76         717567.12       0         400000
# 110       3214.62         720781.74       0         400000
# 111       3220.48         724002.22       0         400000
# 112       3226.36         727228.58       0         400000
# 113       3232.25         730460.83       0         400000
# 114       3238.15         733698.97       0         400000
# 115       3244.06         736943.03       0         400000
# 116       3249.98         740193.01       0         400000
# 117       3255.91         743448.91       0         400000
# 118       3261.85         746710.76       0         400000
# 119       3267.80         749978.57       0         400000
# 120       3273.77         753252.33       0         400000
# 121       3279.74         756532.07       0         400000
# 122       3285.73         759817.80       0         400000
# 123        182.20         760000.00       0         400000
#
# [124 rows x 10 columns]
