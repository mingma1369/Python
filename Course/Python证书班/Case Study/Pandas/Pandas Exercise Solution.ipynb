# %% [markdown]
# # 1- Using Pandas

# %% [markdown]
# ### Importing pandas

# %%
import pandas as pd

# %% [markdown]
# # 2 - Series and DataFrames

# %%
df = pd.read_csv('olympics.csv', skiprows=4)

import numpy as np
np.random.seed(824)
df['age'] = (5*np.random.randn(df.shape[0]) + 25).astype(int)
df['height'] = (5*np.random.randn(df.shape[0]) + 175).astype(int)

# %% [markdown]
# ### Accessing the DataFrame

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %% [markdown]
# ### Accessing Series

# %%
df.Athlete.head()
# Out:
# 0         HAJOS, Alfred
# 1      HERSCHMANN, Otto
# 2     DRIVAS, Dimitrios
# 3    MALOKINIS, Ioannis
# 4    CHASAPIS, Spiridon
# Name: Athlete, dtype: object

# %%
df['Athlete'].head()
# Out:
# 0         HAJOS, Alfred
# 1      HERSCHMANN, Otto
# 2     DRIVAS, Dimitrios
# 3    MALOKINIS, Ioannis
# 4    CHASAPIS, Spiridon
# Name: Athlete, dtype: object

# %%
df[['City','Edition','Athlete']].head()
# Out:
#      City  Edition             Athlete
# 0  Athens     1896       HAJOS, Alfred
# 1  Athens     1896    HERSCHMANN, Otto
# 2  Athens     1896   DRIVAS, Dimitrios
# 3  Athens     1896  MALOKINIS, Ioannis
# 4  Athens     1896  CHASAPIS, Spiridon

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['City'])
# Out:
# pandas.core.series.Series

# %%
type(df.City)
# Out:
# pandas.core.series.Series

# %%
type(df[['City','Edition','Athlete']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 3 - Overview and validation of data
# ### Shape

# %%
df.shape
# Out:
# (29216, 12)

# %%
df.shape[0]
# Out:
# 29216

# %% [markdown]
# ### head() and tail()

# %%
df.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180

# %%
df.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal  age  height
# 29211  GER    Men   84 - 96kg            M  Silver   26     180
# 29212  LTU    Men  96 - 120kg            M  Bronze   14     158
# 29213  ARM    Men  96 - 120kg            M  Bronze   16     170
# 29214  CUB    Men  96 - 120kg            M    Gold   21     171
# 29215  RUS    Men  96 - 120kg            M  Silver   24     168

# %% [markdown]
# ### info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 12 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# age             29216 non-null int64
# height          29216 non-null int64
# dtypes: int64(3), object(9)
# memory usage: 2.7+ MB

# %% [markdown]
# ### describe()

# %%
df.describe()
# Out:
#             Edition           age        height
# count  29216.000000  29216.000000  29216.000000
# mean    1967.713171     24.499179    174.538506
# std       32.406293      5.014502      5.004713
# min     1896.000000      5.000000    153.000000
# 25%     1948.000000     21.000000    171.000000
# 50%     1976.000000     25.000000    175.000000
# 75%     1996.000000     28.000000    178.000000
# max     2008.000000     44.000000    195.000000

# %% [markdown]
# # 4 - Basic Analysis

# %%
df = pd.read_csv('olympics.csv', skiprows=4)
np.random.seed(824)
df['age'] = (5*np.random.randn(df.shape[0]) + 25).astype(int)
df['height'] = (5*np.random.randn(df.shape[0]) + 175).astype(int)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %% [markdown]
# ### value_counts()

# %%
df.Edition.value_counts().head()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# Name: Edition, dtype: int64

# %%
df.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ### sort_values()

# %%
ath = df.Athlete.sort_values()
ath.head()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
# Name: Athlete, dtype: object

# %%
ath = df.Athlete.sort_values(ascending=False)
ath.head()
# Out:
# 8051    ÖSTRAND, Per-Olof
# 596            ÖSTMO, Ole
# 621            ÖSTMO, Ole
# 608            ÖSTMO, Ole
# 603            ÖSTMO, Ole
# Name: Athlete, dtype: object

# %%
df1 = df.sort_values(by=['Edition','age'], ascending=[True,False])
df1.head()
# Out:
#        City  Edition       Sport   Discipline               Athlete  NOC  \
# 114  Athens     1896  Gymnastics  Artistic G.  WEINGÄRTNER, Hermann  GER
# 13   Athens     1896   Athletics    Athletics         BURKE, Thomas  USA
# 9    Athens     1896    Aquatics     Swimming         NEUMANN, Paul  AUT
# 43   Athens     1896   Athletics    Athletics       GARRETT, Robert  USA
# 120  Athens     1896    Shooting     Shooting       NIELSEN, Holger  DEN
#
#     Gender                             Event Event_gender   Medal  age  height
# 114    Men                             vault            M  Bronze   40     174
# 13     Men                              100m            M    Gold   38     173
# 9      Men                    400m freestyle            M    Gold   35     181
# 43     Men                          shot put            M    Gold   35     170
# 120    Men  25m rapid fire pistol (60 shots)            M  Bronze   35     175

# %% [markdown]
# ### drop_duplicates()

# %%
df1.drop_duplicates(subset='Edition', keep='first', inplace=True)

# %%
df1
# Out:
#                         City  Edition          Sport     Discipline  \
# 114                   Athens     1896     Gymnastics    Artistic G.
# 338                    Paris     1900        Croquet        Croquet
# 762                 St Louis     1904      Athletics      Athletics
# 1768                  London     1908       Shooting       Shooting
# 2236               Stockholm     1912        Fencing        Fencing
# 2918                 Antwerp     1920        Archery        Archery
# 4853                   Paris     1924       Shooting       Shooting
# 5137               Amsterdam     1928      Athletics      Athletics
# 6265             Los Angeles     1932        Sailing        Sailing
# 6514                  Berlin     1936      Athletics      Athletics
# 7832                  London     1948         Rowing         Rowing
# 8615                Helsinki     1952     Gymnastics    Artistic G.
# 9281   Melbourne / Stockholm     1956        Cycling  Cycling Track
# 9981                    Rome     1960      Athletics      Athletics
# 10756                  Tokyo     1964       Aquatics       Swimming
# 11935                 Mexico     1968      Athletics      Athletics
# 13370                 Munich     1972       Football       Football
# 13986               Montreal     1976       Aquatics       Swimming
# 16281                 Moscow     1980         Rowing         Rowing
# 17001            Los Angeles     1984     Basketball     Basketball
# 19391                  Seoul     1988       Shooting       Shooting
# 21216              Barcelona     1992  Weightlifting  Weightlifting
# 22784                Atlanta     1996         Rowing         Rowing
# 24437                 Sydney     2000       Handball       Handball
# 25715                 Athens     2004      Badminton      Badminton
# 28777                Beijing     2008         Rowing         Rowing
#
#                         Athlete  NOC Gender  \
# 114        WEINGÄRTNER, Hermann  GER    Men
# 338                       JOHIN  FRA    Men
# 762         PILGRIM, Paul Harry  USA    Men
# 1768     CARNELL, Arthur Ashton  GBR    Men
# 2236         GOLLING, Friedrich  AUT    Men
# 2918           CLOETENS, Edmond  BEL    Men
# 4853              LIBERG, Einar  NOR    Men
# 5137             THOMPSON, Jean  CAN  Women
# 6265       RATSEY, George Colin  GBR    Men
# 6514               CSAK, Ibolya  HUN  Women
# 7832         LARSEN, Aage Ernst  DEN    Men
# 8615            KORONDI, Margit  HUN  Women
# 9281       LECANTE, Jean-Claude  FRA    Men
# 9981         DAVIS, Glenn Ashby  USA    Men
# 10756  SCHMIDT, Frederick Weber  USA    Men
# 11935           KEINO, Kipchoge  KEN    Men
# 13370          DEYNA, Kazimierz  POL    Men
# 13986            PRIEMER, Petra  GDR  Women
# 16281             UMANETS, Nina  URS  Women
# 17001     DONOVAN, Anne Theresa  USA  Women
# 19391           MONAKOV, Dmitri  URS    Men
# 21216             LUO, Jianming  CHN    Men
# 22784      HANSON, Boden Joseph  AUS    Men
# 24437         DUVHOLT, Kristine  NOR  Women
# 25715                 HIAN, Eng  INA    Men
# 28777       SCHILLER, Stephanie  GER  Women
#
#                                         Event Event_gender   Medal  age  \
# 114                                     vault            M  Bronze   40
# 338                         individual 1 ball            M  Silver   38
# 762                               4miles team            M    Gold   42
# 1768               50m rifle prone (60 shots)            M    Gold   40
# 2236                               sabre team            M  Silver   38
# 2918      fixed bird target small bird, teams            M    Gold   40
# 4853    100m running deer, double shots, team            M  Silver   39
# 5137                             4x100m relay            W    Gold   43
# 6265          two-person keelboat open (Star)            X  Silver   39
# 6514                                high jump            W    Gold   40
# 7832                       double sculls (2x)            M  Silver   44
# 8615                 team, portable apparatus            W  Bronze   42
# 9281                     Team Pursuit (4000m)            M  Silver   39
# 9981                             4x400m relay            M    Gold   41
# 10756                     4x100m medley relay            M    Gold   41
# 11935                                   5000m            M  Silver   42
# 13370                                football            M    Gold   40
# 13986                  4x100m freestyle relay            W  Silver   38
# 16281                eight with coxswain (8+)            W  Silver   44
# 17001                              basketball            W    Gold   40
# 19391                      trap (125 targets)            X    Gold   43
# 21216            - 56kg, total (bantamweight)            M  Bronze   40
# 22784  quadruple sculls without coxswain (4x)            M  Bronze   42
# 24437                                handball            W  Bronze   40
# 25715                                 doubles            M  Bronze   40
# 28777  quadruple sculls without coxswain (4x)            W  Bronze   42
#
#        height
# 114       174
# 338       165
# 762       170
# 1768      171
# 2236      177
# 2918      175
# 4853      177
# 5137      181
# 6265      166
# 6514      177
# 7832      169
# 8615      170
# 9281      177
# 9981      176
# 10756     175
# 11935     178
# 13370     175
# 13986     177
# 16281     174
# 17001     165
# 19391     175
# 21216     171
# 22784     178
# 24437     170
# 25715     172
# 28777     183

# %% [markdown]
# ### Boolean indexing

# %%
df[(df.Medal=='Gold') & (df.City=='Beijing') & ((df.Event=='100m')|(df.Event=='200m'))]
# Out:
#           City  Edition      Sport Discipline                   Athlete  NOC  \
# 27552  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27554  Beijing     2008  Athletics  Athletics        FRASER, Shelly-ann  JAM
# 27570  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27573  Beijing     2008  Athletics  Athletics  CAMPBELL-BROWN, Veronica  JAM
#
#       Gender Event Event_gender Medal  age  height
# 27552    Men  100m            M  Gold   28     167
# 27554  Women  100m            W  Gold   20     180
# 27570    Men  200m            M  Gold   24     177
# 27573  Women  200m            W  Gold   28     181

# %% [markdown]
# ### String handling

# %%
df[df.Athlete.str.contains('Usain')]
# Out:
#           City  Edition      Sport Discipline      Athlete  NOC Gender  \
# 27552  Beijing     2008  Athletics  Athletics  BOLT, Usain  JAM    Men
# 27570  Beijing     2008  Athletics  Athletics  BOLT, Usain  JAM    Men
# 27603  Beijing     2008  Athletics  Athletics  BOLT, Usain  JAM    Men
#
#               Event Event_gender Medal  age  height
# 27552          100m            M  Gold   28     167
# 27570          200m            M  Gold   24     177
# 27603  4x100m relay            M  Gold   32     179

# %% [markdown]
# # 5 - Indexing

# %%
df = pd.read_csv('olympics.csv', skiprows=4)
np.random.seed(824)
df['age'] = (5*np.random.randn(df.shape[0]) + 25).astype(int)
df['height'] = (5*np.random.randn(df.shape[0]) + 175).astype(int)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %% [markdown]
# ### Index

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.index[100]
# Out:
# 100

# %% [raw]
# df.index[100] = 5

# %% [markdown]
# ### set_index() and reset_index()

# %%
df.set_index('Athlete').head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal  age  \
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold   17
# HERSCHMANN, Otto                100m freestyle            M  Silver   22
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze   21
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold   32
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver   25
#
#                     height
# Athlete
# HAJOS, Alfred          176
# HERSCHMANN, Otto       172
# DRIVAS, Dimitrios      180
# MALOKINIS, Ioannis     179
# CHASAPIS, Spiridon     173

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %%
df.set_index('Athlete',inplace=True)

# %%
df.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal  age  \
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold   17
# HERSCHMANN, Otto                100m freestyle            M  Silver   22
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze   21
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold   32
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver   25
#
#                     height
# Athlete
# HAJOS, Alfred          176
# HERSCHMANN, Otto       172
# DRIVAS, Dimitrios      180
# MALOKINIS, Ioannis     179
# CHASAPIS, Spiridon     173

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %% [markdown]
# ### sort_index()

# %%
df1 = df.set_index('Athlete')
df1.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal  age  \
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold   17
# HERSCHMANN, Otto                100m freestyle            M  Silver   22
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze   21
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold   32
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver   25
#
#                     height
# Athlete
# HAJOS, Alfred          176
# HERSCHMANN, Otto       172
# DRIVAS, Dimitrios      180
# MALOKINIS, Ioannis     179
# CHASAPIS, Spiridon     173

# %%
df1.sort_index(inplace=True,ascending=False)
df1.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal  age  \
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze   22
# ÖSTMO, Ole                      free rifle, team            M  Silver   14
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver   23
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze   16
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze   29
#
#                    height
# Athlete
# ÖSTRAND, Per-Olof     175
# ÖSTMO, Ole            176
# ÖSTMO, Ole            172
# ÖSTMO, Ole            177
# ÖSTMO, Ole            178

# %% [markdown]
# ### loc[...]

# %%
df1.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
#
#             Event_gender Medal  age  height
# Athlete
# BOLT, Usain            M  Gold   32     179
# BOLT, Usain            M  Gold   24     177
# BOLT, Usain            M  Gold   28     167

# %%
df.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %%
df.loc[df.Athlete == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal  age  height
# 27552          100m            M  Gold   28     167
# 27570          200m            M  Gold   24     177
# 27603  4x100m relay            M  Gold   32     179

# %% [markdown]
# ### iloc[...]

# %%
df.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# age                        21
# height                    180
# Name: 1700, dtype: object

# %%
df.iloc[[1542, 2390,6000,15000]]
# Out:
#                         Athlete         City  Edition       Sport  \
# 1542     DUCKETT, Richard Louis       London     1908    Lacrosse
# 2390         SAASTAMOINEN, Eino    Stockholm     1912  Gymnastics
# 6000            AGOSTONI, Carlo  Los Angeles     1932     Fencing
# 15000  JENSEN, Poul Richard Hoj     Montreal     1976     Sailing
#
#         Discipline  NOC Gender                                    Event  \
# 1542      Lacrosse  CAN    Men                                 lacrosse
# 2390   Artistic G.  FIN    Men                        team, free system
# 6000       Fencing  ITA    Men                          épée individual
# 15000      Sailing  DEN    Men  fleet/match race keelboat open (Soling)
#
#       Event_gender   Medal  age  height
# 1542             M    Gold   24     170
# 2390             M  Silver   23     173
# 6000             M  Bronze   14     173
# 15000            X    Gold   26     171

# %%
df.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %%
df.iloc[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179

# %%
df.iloc[1:4,0:4]
# Out:
#               Athlete    City  Edition     Sport
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics

# %% [markdown]
# # 6 - Groupby

# %%
df = pd.read_csv('olympics.csv', skiprows=4)
np.random.seed(824)
df['age'] = (5*np.random.randn(df.shape[0]) + 25).astype(int)
df['height'] = (5*np.random.randn(df.shape[0]) + 175).astype(int)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %% [markdown]
# ### The Groupby object

# %%
df.groupby('Edition')

# %%
type(df.groupby('Edition'))
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %% [markdown]
# ### Groupby computations

# %% [markdown]
# ** size() **

# %%
df.groupby('Edition').size().head()
# Out:
# Edition
# 1896    151
# 1900    512
# 1904    470
# 1908    804
# 1912    885
# dtype: int64

# %%
df.groupby(['Edition','NOC','Medal']).size().head()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
# dtype: int64

# %% [markdown]
# ** agg({  : [ ... ]}) **

# %%
df1 = df.groupby(['Edition','NOC','Medal']).agg({'age':['min','max','count','mean']}).head()
df1.head()
# Out:
#                    age
#                    min max count       mean
# Edition NOC Medal
# 1896    AUS Gold    17  18     2  17.500000
#         AUT Bronze  28  30     2  29.000000
#             Gold    19  35     2  27.000000
#             Silver  22  22     1  22.000000
#         DEN Bronze  24  35     3  28.666667

# %% [markdown]
# # 7 - Reshaping

# %%
df = pd.read_csv('olympics.csv', skiprows=4)

np.random.seed(824)
df['age'] = (5*np.random.randn(df.shape[0]) + 25).astype(int)
df['height'] = (5*np.random.randn(df.shape[0]) + 175).astype(int)

df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal  age  height
# 0              100m freestyle            M    Gold   17     176
# 1              100m freestyle            M  Silver   22     172
# 2  100m freestyle for sailors            M  Bronze   21     180
# 3  100m freestyle for sailors            M    Gold   32     179
# 4  100m freestyle for sailors            M  Silver   25     173

# %% [markdown]
# ### stack() and unstack()

# %%
df1 = df[(df.Edition == 2008) & (df.Gender=='Men') & ((df.Event == '100m')|(df.Event == '200m'))]
df1
# Out:
#           City  Edition      Sport Discipline            Athlete  NOC Gender  \
# 27551  Beijing     2008  Athletics  Athletics        DIX, Walter  USA    Men
# 27552  Beijing     2008  Athletics  Athletics        BOLT, Usain  JAM    Men
# 27553  Beijing     2008  Athletics  Athletics  THOMPSON, Richard  TRI    Men
# 27569  Beijing     2008  Athletics  Athletics        DIX, Walter  USA    Men
# 27570  Beijing     2008  Athletics  Athletics        BOLT, Usain  JAM    Men
# 27571  Beijing     2008  Athletics  Athletics    CRAWFORD, Shawn  USA    Men
#
#       Event Event_gender   Medal  age  height
# 27551  100m            M  Bronze   26     174
# 27552  100m            M    Gold   28     167
# 27553  100m            M  Silver   31     179
# 27569  200m            M  Bronze   22     172
# 27570  200m            M    Gold   24     177
# 27571  200m            M  Silver   18     174

# %%
df2 = df1.groupby(['NOC','Gender','Event']).size()
df2
# Out:
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
# TRI  Men     100m     1
# USA  Men     100m     1
#              200m     2
# dtype: int64

# %%
df3 = df2.unstack(['Event'])
df3
# Out:
# Event       100m  200m
# NOC Gender
# JAM Men      1.0   1.0
# TRI Men      1.0   NaN
# USA Men      1.0   2.0

# %%
df3 = df2.unstack(['Event'], fill_value=0)
df3
# Out:
# Event       100m  200m
# NOC Gender
# JAM Men        1     1
# TRI Men        1     0
# USA Men        1     2

# %%
df3.index
# Out:
# MultiIndex(levels=[['JAM', 'TRI', 'USA'], ['Men']],
#            labels=[[0, 1, 2], [0, 0, 0]],
#            names=['NOC', 'Gender'])

# %%
df3.columns
# Out:
# Index(['100m', '200m'], dtype='object', name='Event')

# %%
df4 = df3.copy()

# %%
df4.columns.name
# Out:
# 'Event'

# %%
df4.columns.name = None

# %%
df4
# Out:
#             100m  200m
# NOC Gender
# JAM Men        1     1
# TRI Men        1     0
# USA Men        1     2

# %%
df3
# Out:
# Event       100m  200m
# NOC Gender
# JAM Men        1     1
# TRI Men        1     0
# USA Men        1     2

# %%
df3.stack()
# Out:
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
# TRI  Men     100m     1
#              200m     0
# USA  Men     100m     1
#              200m     2
# dtype: int64
